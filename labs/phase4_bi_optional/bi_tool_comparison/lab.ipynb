# %% [markdown]
# # Optional Lab — BI Tool Comparison (Solution Guide)

# %% [markdown]
# ## 1) Scope
# So sánh cùng một bài toán dashboard ở 2 hướng: BI tool vs code-first.

# %%
# TODO: hoàn thiện cell này theo đề bài

# %% [markdown]
# ## 2) Reflection
# - Khi nào BI tool vượt trội?
# - Khi nào code-first bắt buộc?
# - Mô hình hybrid phù hợp cho team của bạn?
