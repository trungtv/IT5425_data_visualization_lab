# %% [markdown]
# # Seaborn 04 - Categorical Comparisons

# %% [markdown]
# **Trong tam:** barplot/pointplot/boxplot/violinplot/swarmplot va uoc luong uncertainty.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# TODO: hoan thien phan code theo de bai

# %%
# TODO: hoan thien phan code theo de bai

# %%
# TODO: hoan thien phan code theo de bai

# %%
# TODO: hoan thien phan code theo de bai

# %% [markdown]
# ## Reflection
# - Tom tat 2-3 insight chinh.
# - Neu phai giao cho stakeholder, ban chon 1 chart nao va vi sao?
