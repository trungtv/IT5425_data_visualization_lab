# %% [markdown]
# # Seaborn 03 - Relational and Regression Views

# %% [markdown]
# **Trong tam:** scatterplot/lineplot/relplot/lmplot de tim quan he bien.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# TODO: hoan thien phan code theo de bai

# %%
# TODO: hoan thien phan code theo de bai

# %%
# TODO: hoan thien phan code theo de bai

# %%
# TODO: hoan thien phan code theo de bai

# %% [markdown]
# ## Reflection
# - Tom tat 2-3 insight chinh.
# - Neu phai giao cho stakeholder, ban chon 1 chart nao va vi sao?
