# %% [markdown]
# # Seaborn 06 - Theme, Palette, and Objects API

# %% [markdown]
# **Trong tam:** set_theme, color palette va gioi thieu seaborn.objects (0.12+).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# TODO: hoan thien phan code theo de bai

# %%
# TODO: hoan thien phan code theo de bai

# %%
import seaborn.objects as so

# TODO: hoan thien phan code theo de bai

# %% [markdown]
# ## Reflection
# - Tom tat 2-3 insight chinh.
# - Neu phai giao cho stakeholder, ban chon 1 chart nao va vi sao?
