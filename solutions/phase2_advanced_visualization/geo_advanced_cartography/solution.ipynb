# %% [markdown]
# # Advanced Geo Cartography (Solution)
#
# Practice classification, projection choice, and map design diagnostics.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

sns.set_theme(style="whitegrid")

def resolve_repo_root() -> Path:
    cwd = Path.cwd().resolve()
    for p in [cwd, *cwd.parents]:
        if (p / "data" / "gapminder.csv").exists():
            return p
    raise FileNotFoundError("Cannot locate data/gapminder.csv")

root = resolve_repo_root()
df = pd.read_csv(root / "data" / "gapminder.csv")
d2007 = df[df["year"] == 2007].copy()

# %% [markdown]
# ## 1) Quantile classification choropleth

# %%
tmp = d2007[['iso_alpha','country','lifeExp']].dropna()
q = pd.qcut(tmp['lifeExp'], q=5, labels=False, duplicates='drop')
tmp = tmp.assign(lifeExp_quantile=q)
fig = px.choropleth(tmp, locations='iso_alpha', color='lifeExp_quantile', hover_name='country', color_continuous_scale='Viridis')
fig.update_layout(title='Quantile-classed choropleth (lifeExp)')
fig.show()

# %% [markdown]
# ## 2) Projection comparison

# %%
for proj in ['natural earth','mercator','orthographic']:
    fig = px.choropleth(d2007, locations='iso_alpha', color='gdpPercap', hover_name='country', color_continuous_scale='Cividis', projection=proj)
    fig.update_layout(title=f'Projection: {proj}')
    fig.show()

# %% [markdown]
# ## Reflection
# - Nêu 2 điểm học được về chart selection.
# - Chỉ ra 1 rủi ro diễn giải sai với loại chart trong lab này.
