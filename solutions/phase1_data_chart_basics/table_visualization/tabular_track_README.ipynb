# %% [markdown]
# # Table visualization — chi dan track
#
# ### A) Visualization **cho du lieu dang bang** (khuyen nghi theo syllabus)
# 1. `tabular_univariate_profiling/solution.ipynb`
# 2. `tabular_bivariate_relationships/solution.ipynb`
# 3. `tabular_multivariate_structure/solution.ipynb`
# 4. `tabular_wide_pattern_discovery/solution.ipynb`
# 5. `tabular_storytelling/solution.ipynb`
#
# ### B) Legacy (framework theo nhom chart axes/scales)
# - `legacy_chapter_aligned/solution.ipynb`
#
# Exercise tuong ung nam trong `labs/phase1_data_chart_basics/table_visualization/<cung ten thu muc>/lab.ipynb`.
